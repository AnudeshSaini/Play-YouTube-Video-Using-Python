# %%
# Installing and importing the module
# !pip install pywhatkit
import pywhatkit as pwt

# %%
# using Exception Handling to avoid exceptions
try:
        
# Play turorial video to Handle Missing Values from Krish Naik youtube channel 

    pwt.playonyt("All Techniques To Handle Missing Values by Krish Naik")
    print("Playing...")
    
# printing the error message if any error occurs 

except:
    
    print("Network Error Occured")
# Out:
# Playing...
